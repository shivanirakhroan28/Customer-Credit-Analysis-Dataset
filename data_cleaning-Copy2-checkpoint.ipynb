# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\shivani\Downloads\train.csv")

# %%
df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
df.head(10)
# Out:
#        ID Customer_ID     Month             Name   Age          SSN  \
# 0  0x1602   CUS_0xd40   January    Aaron Maashoh    23  821-00-0265
# 1  0x1603   CUS_0xd40  February    Aaron Maashoh    23  821-00-0265
# 2  0x1604   CUS_0xd40     March    Aaron Maashoh  -500  821-00-0265
# 3  0x1605   CUS_0xd40     April    Aaron Maashoh    23  821-00-0265
# 4  0x1606   CUS_0xd40       May    Aaron Maashoh    23  821-00-0265
# 5  0x1607   CUS_0xd40      June    Aaron Maashoh    23  821-00-0265
# 6  0x1608   CUS_0xd40      July    Aaron Maashoh    23  821-00-0265
# 7  0x1609   CUS_0xd40    August              NaN    23    #F%$D@*&8
# 8  0x160e  CUS_0x21b1   January  Rick Rothackerj   28_  004-07-5839
# 9  0x160f  CUS_0x21b1  February  Rick Rothackerj    28  004-07-5839
#
#   Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0  Scientist      19114.12            1824.843333                  3  ...
# ...

# %%
df[["Month"]].isna().sum()
# Out:
# Month    0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                          object
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
df[["Name"]]
# Out:
#                 Name
# 0      Aaron Maashoh
# 1      Aaron Maashoh
# 2      Aaron Maashoh
# 3      Aaron Maashoh
# 4      Aaron Maashoh
# ...              ...
# 99995          Nicks
# 99996          Nicks
# 99997          Nicks
# 99998          Nicks
# 99999          Nicks
#
# [100000 rows x 1 columns]

# %%
df[["Name"]]=df[["Name"]].ffill()

# %%
df[["Name"]].isna().sum()
# Out:
# Name    0
# dtype: int64

# %%
df[["Age"]].isna().sum()
# Out:
# Age    0
# dtype: int64

# %%
ls=[]
for i in df["Age"]:
    text=str(i).split("_")[0]
    ls.append(text)

# %%
df["Age"]=ls

# %%
df["Age"]=df["Age"].astype("int")

# %%
df.dtypes
# Out:
# ID                           object
# Customer_ID                  object
# Month                        object
# Name                         object
# Age                           int64
# SSN                          object
# Occupation                   object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Num_of_Loan                  object
# Type_of_Loan                 object
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Changed_Credit_Limit         object
# Num_Credit_Inquiries        float64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# ...

# %%
df["Age"].mean()
# Out:
# np.float64(110.6497)

# %%
Mini= df["Age"].min()
Q1= df["Age"].quantile(0.25)
Q2= df["Age"].quantile(0.50)
Q3= df["Age"].quantile(0.75)
Max= df["Age"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 69.0
# lower= -3.0

# %%
df[df["Age"]<lower_fence]
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 2       0x1604   CUS_0xd40     March     Aaron Maashoh -500  821-00-0265
# 113     0x16ab   CUS_0xff4  February         Poornimaf -500  655-05-7666
# 289     0x17b3  CUS_0x4080  February         ra Alperx -500  995-37-8920
# 340     0x17fe  CUS_0x9bc1       May      Jaisinghanij -500  445-18-4420
# 560     0x194a  CUS_0x2827   January             Lisah -500  486-07-1289
# ...        ...         ...       ...               ...  ...          ...
# 99531  0x25d31  CUS_0x85dd     April          Lucianam -500  767-36-7303
# 99541  0x25d3f  CUS_0xc22f      June         McMillanw -500  795-34-9348
# 99762  0x25e8c  CUS_0x1b07     March          Baldwinq -500  739-15-8297
# 99937  0x25f93  CUS_0xad4f  February  Sabina Zawadzkig -500  226-45-0652
# 99963  0x25fb9  CUS_0x372c     April   Lucia Mutikanik -500  340-85-7301
#
#          Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Age"]<lower_fence,"Age"]= 35

# %%
df[df["Age"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Age"]>upper_fence]
# Out:
#             ID Customer_ID     Month            Name   Age          SSN  \
# 56      0x1656  CUS_0x5407   January            Annk  7580  500-92-6408
# 122     0x16b8  CUS_0x33d2     March       Chalmersa   181  965-46-2491
# 219     0x1749  CUS_0x3edc     April       Williamso   995  663-16-3845
# 243     0x176d  CUS_0x9a71     April   Mukhopadhyayc  5079  889-07-2357
# 288     0x17b2  CUS_0x4080   January       ra Alperx  6409  995-37-8920
# ...        ...         ...       ...             ...   ...          ...
# 99877  0x25f37  CUS_0x3855      June           Xolai  6476  963-55-7106
# 99908  0x25f66  CUS_0xa053       May       t Astridn  4808  094-81-5856
# 99913  0x25f6f  CUS_0x1619  February     Phil Wahbao  2263  683-59-7399
# 99950  0x25fa4  CUS_0x51b3      July           Ryana  1342  837-85-9800
# 99972  0x25fc6   CUS_0xf16       May  Maria Sheahanb  1753  868-70-2218
#
#           Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Age"]>upper_fence,"Age"]= 35

# %%
df[df["Age"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
#F%$D@*&8

# %%
df[["SSN"]]
# Out:
#                SSN
# 0      821-00-0265
# 1      821-00-0265
# 2      821-00-0265
# 3      821-00-0265
# 4      821-00-0265
# ...            ...
# 99995  078-73-5990
# 99996  078-73-5990
# 99997  078-73-5990
# 99998  078-73-5990
# 99999  078-73-5990
#
# [100000 rows x 1 columns]

# %%
df["SSN"]=df["SSN"].replace("#F%$D@*&8",np.nan) # replacing value to null value

# %%
df.dropna(subset='SSN',inplace=True)

# %%
df.head(10)
# Out:
#         ID Customer_ID     Month             Name  Age          SSN  \
# 0   0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265
# 1   0x1603   CUS_0xd40  February    Aaron Maashoh   23  821-00-0265
# 2   0x1604   CUS_0xd40     March    Aaron Maashoh   35  821-00-0265
# 3   0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265
# 4   0x1606   CUS_0xd40       May    Aaron Maashoh   23  821-00-0265
# 5   0x1607   CUS_0xd40      June    Aaron Maashoh   23  821-00-0265
# 6   0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265
# 8   0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9   0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839
# 10  0x1610  CUS_0x21b1     March  Rick Rothackerj   28  004-07-5839
#
#    Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0   Scientist      19114.12            1824.843333                  3  ...
# ...

# %%
df["SSN"]
# Out:
# 0        821-00-0265
# 1        821-00-0265
# 2        821-00-0265
# 3        821-00-0265
# 4        821-00-0265
#             ...
# 99995    078-73-5990
# 99996    078-73-5990
# 99997    078-73-5990
# 99998    078-73-5990
# 99999    078-73-5990
# Name: SSN, Length: 94428, dtype: object

# %%
df.isna().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                            0
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       14143
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                10758
# Delay_from_due_date             0
# Num_of_Delayed_Payment       6614
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1861
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           8525
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4227
# Payment_Behaviour               0
# Monthly_Balance              1134
# ...

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# _______          6629
# Lawyer           6197
# Engineer         5999
# Architect        5982
# Scientist        5949
# Mechanic         5939
# Accountant       5917
# Teacher          5907
# Developer        5900
# Media_Manager    5894
# Entrepreneur     5799
# Doctor           5764
# Journalist       5753
# Manager          5638
# Musician         5605
# Writer           5556
# Name: count, dtype: int64

# %%
df["Occupation"]=df["Occupation"].replace("_______","Others")

# %%
df["Occupation"]
# Out:
# 0        Scientist
# 1        Scientist
# 2        Scientist
# 3        Scientist
# 4        Scientist
#            ...
# 99995     Mechanic
# 99996     Mechanic
# 99997     Mechanic
# 99998     Mechanic
# 99999     Mechanic
# Name: Occupation, Length: 94428, dtype: object

# %%
df["Occupation"].value_counts()
# Out:
# Occupation
# Others           6629
# Lawyer           6197
# Engineer         5999
# Architect        5982
# Scientist        5949
# Mechanic         5939
# Accountant       5917
# Teacher          5907
# Developer        5900
# Media_Manager    5894
# Entrepreneur     5799
# Doctor           5764
# Journalist       5753
# Manager          5638
# Musician         5605
# Writer           5556
# Name: count, dtype: int64

# %%
df["Annual_Income"].isna().sum()
# Out:
# np.int64(0)

# %%
ls=[]
for i in df["Annual_Income"]:
    text=str(i).split("_")[0]
    ls.append(text)

# %%
df["Annual_Income"]=ls

# %%
df["Annual_Income"]=df["Annual_Income"].astype("float")

# %%
df["Annual_Income"].mean()
# Out:
# np.float64(174154.03160084932)

# %%
df["Annual_Income"].skew()
# Out:
# np.float64(12.624893917730594)

# %%
df["Annual_Income"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Annual_Income"].min()
Q1= df["Annual_Income"].quantile(0.25)
Q2= df["Annual_Income"].quantile(0.50)
Q3= df["Annual_Income"].quantile(0.75)
Max= df["Annual_Income"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 152923.725
# lower= -60629.354999999996

# %%
df[df["Annual_Income"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Annual_Income"]>upper_fence]
# Out:
#             ID Customer_ID     Month                Name  Age          SSN  \
# 231     0x1759  CUS_0xbffe    August  Dhanya Skariachano   40  311-13-7309
# 245     0x176f  CUS_0x9a71      June       Mukhopadhyayc   55  889-07-2357
# 361     0x181f  CUS_0x8e9b  February  Rachelle Younglaic   15  925-51-5335
# 368     0x182a  CUS_0x609d   January  Rachelle Younglaic   27  911-47-6879
# 379     0x1839  CUS_0x75c6     April    "John ODonnell"p   30  587-65-8904
# ...        ...         ...       ...                 ...  ...          ...
# 99664  0x25dfa   CUS_0xb09   January              Lianau   31  228-47-4867
# 99714  0x25e44  CUS_0xadbd     March              Scotts   26  864-24-3672
# 99721  0x25e4f  CUS_0x11c7  February      raden Reddallh   53  646-19-1493
# 99882  0x25f40  CUS_0x47fa     March    Yantoultra Nguif   31  291-51-7240
# 99945  0x25f9f  CUS_0x51b3  February               Ryana   33  837-85-9800
#
# ...

# %%
df.loc[df["Annual_Income"]>upper_fence,"Annual_Income"]= 33

# %%
df[df["Annual_Income"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df["Monthly_Inhand_Salary"].isna().sum()
# Out:
# np.int64(14143)

# %%
mean= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].mean())
median= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].median())
std= df["Monthly_Inhand_Salary"].fillna(df["Monthly_Inhand_Salary"].std())
ffill= df["Monthly_Inhand_Salary"].ffill()
bfill= df["Monthly_Inhand_Salary"].bfill()
const= df["Monthly_Inhand_Salary"].fillna(0)

# %%
print("the mean is=",mean.mean())
print("the median is=",median.mean())
print("the std is=",std.mean())
print("the ffill is=",ffill.mean())
print("the bfill is=",bfill.mean())
print("the const is=",const.mean())
# Out:
# the mean is= 4195.968455110987
# the median is= 4030.529176147459
# the std is= 4044.9208280782605
# the ffill is= 4198.5593674379115
# the bfill is= 4201.359575494231
# the const is= 3567.5152223766854

# %%
print("The Actual Mean is=",df["Monthly_Inhand_Salary"].mean())
# Out:
# The Actual Mean is= 4195.968455110988

# %%
ffill.std()
# Out:
# np.float64(3192.101294498842)

# %%
bfill.std()
# Out:
# np.float64(3189.6621380643032)

# %%
mean.std()
# Out:
# np.float64(2939.0919228166454)

# %%
median.std()
# Out:
# np.float64(2965.4062176686352)

# %%
df["Monthly_Inhand_Salary"].std()
# Out:
# np.float64(3187.47483102513)

# %%
df["Monthly_Inhand_Salary"]=df["Monthly_Inhand_Salary"].bfill()

# %%
df["Monthly_Inhand_Salary"]
# Out:
# 0        1824.843333
# 1        1824.843333
# 2        1824.843333
# 3        1824.843333
# 4        1824.843333
#             ...
# 99995    3359.415833
# 99996    3359.415833
# 99997    3359.415833
# 99998    3359.415833
# 99999    3359.415833
# Name: Monthly_Inhand_Salary, Length: 94428, dtype: float64

# %%
df["Monthly_Inhand_Salary"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Num_Bank_Accounts"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Num_Bank_Accounts"].astype("int")
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 99995    4
# 99996    4
# 99997    4
# 99998    4
# 99999    4
# Name: Num_Bank_Accounts, Length: 94428, dtype: int64

# %%
Mini= df["Num_Bank_Accounts"].min()
Q1= df["Num_Bank_Accounts"].quantile(0.25)
Q2= df["Num_Bank_Accounts"].quantile(0.50)
Q3= df["Num_Bank_Accounts"].quantile(0.75)
Max= df["Num_Bank_Accounts"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 13.0
# lower= -3.0

# %%
df[df["Num_Bank_Accounts"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Num_Bank_Accounts"]>upper_fence]
# Out:
#             ID Customer_ID    Month             Name  Age          SSN  \
# 267     0x1791  CUS_0x4004    April          Carlosj   44  679-26-6464
# 288     0x17b2  CUS_0x4080  January        ra Alperx   35  995-37-8920
# 310     0x17d0  CUS_0x42ac     July        Lawrencea   37  700-60-3660
# 339     0x17fd  CUS_0x9bc1    April     Jaisinghanij   42  445-18-4420
# 356     0x1816  CUS_0xaedb      May     Olivia Oranr   19  272-47-1135
# ...        ...         ...      ...              ...  ...          ...
# 99591  0x25d89   CUS_0x544   August  Jon Herskovitzu   29  163-45-1172
# 99638  0x25dd0  CUS_0x296f     July  David Millikenh   25  972-13-0672
# 99666  0x25dfc   CUS_0xb09    March           Lianau   31  228-47-4867
# 99722  0x25e50  CUS_0x11c7    March   raden Reddallh   53  646-19-1493
# 99916  0x25f72  CUS_0x1619      May      Phil Wahbao   54  683-59-7399
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Num_Bank_Accounts"]>upper_fence,"Num_Bank_Accounts"]=10

# %%
df[df["Num_Bank_Accounts"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df["Num_Credit_Card"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Num_Credit_Card"].min()
Q1= df["Num_Credit_Card"].quantile(0.25)
Q2= df["Num_Credit_Card"].quantile(0.50)
Q3= df["Num_Credit_Card"].quantile(0.75)
Max= df["Num_Credit_Card"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 11.5
# lower= -0.5

# %%
df[df["Num_Credit_Card"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Num_Credit_Card"]>upper_fence]
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 10      0x1610  CUS_0x21b1     March   Rick Rothackerj   28  004-07-5839
# 40      0x163e  CUS_0x95ee   January                Np   31  612-70-8987
# 163     0x16f5  CUS_0x132f     April  Mark Felsenthald   41  561-60-9294
# 215     0x1741  CUS_0xb95f    August           Ashleyk   30  467-13-1148
# 280     0x17a6  CUS_0x9b94   January               Bri   36  734-54-7098
# ...        ...         ...       ...               ...  ...          ...
# 99611  0x25da9  CUS_0x2829     April    Alistair Barre   31  172-85-1573
# 99615  0x25dad  CUS_0x2829    August    Alistair Barre   32  172-85-1573
# 99619  0x25db5  CUS_0xae66     April              Jino   30  721-45-4479
# 99769  0x25e97  CUS_0xc345  February       Jeb Blountf   23  176-40-0757
# 99811  0x25ed5  CUS_0x64f0     April          McBrideh   19  655-81-0974
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Num_Credit_Card"]>upper_fence,"Num_Credit_Card"]=8.2

# %%
df[df["Num_Credit_Card"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df["Interest_Rate"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Interest_Rate"].min()
Q1= df["Interest_Rate"].quantile(0.25)
Q2= df["Interest_Rate"].quantile(0.50)
Q3= df["Interest_Rate"].quantile(0.75)
Max= df["Interest_Rate"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 38.0
# lower= -10.0

# %%
df[df["Interest_Rate"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Interest_Rate"]>upper_fence]
# Out:
#             ID Customer_ID     Month                Name  Age          SSN  \
# 44      0x1642  CUS_0x95ee       May                  Np   31  612-70-8987
# 89      0x1687  CUS_0xc0ab  February            Soyoungd   33  342-90-2649
# 167     0x16f9  CUS_0x132f    August    Mark Felsenthald   41  561-60-9294
# 229     0x1757  CUS_0xbffe      June  Dhanya Skariachano   40  311-13-7309
# 325     0x17e7  CUS_0xb5ff      June               Nateg   33  060-81-1328
# ...        ...         ...       ...                 ...  ...          ...
# 99753  0x25e7f  CUS_0x4a8f  February      Doris Frankelm   24  021-30-1201
# 99791  0x25eb5  CUS_0x62f5    August             Alexein   54  272-40-2510
# 99801  0x25ec7  CUS_0x1232  February            Crawleyv   16  441-26-1297
# 99882  0x25f40  CUS_0x47fa     March    Yantoultra Nguif   31  291-51-7240
# 99997  0x25feb  CUS_0x942c      June               Nicks   25  078-73-5990
#
# ...

# %%
df.loc[df["Interest_Rate"]>upper_fence,"Interest_Rate"]=9

# %%
df[df["Interest_Rate"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Num_of_Loan"]].isna().sum()
# Out:
# Num_of_Loan    0
# dtype: int64

# %%
ls=[]
for i in df["Num_of_Loan"]:
    text= str(i).split("_")[0]
    ls.append(text)

# %%
df["Num_of_Loan"]=ls

# %%
df["Num_of_Loan"]=df["Num_of_Loan"].astype("int")

# %%
df["Num_of_Loan"].mean()
# Out:
# np.float64(3.0587219892404796)

# %%
df["Num_of_Loan"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Num_of_Loan"].min()
Q1= df["Num_of_Loan"].quantile(0.25)
Q2= df["Num_of_Loan"].quantile(0.50)
Q3= df["Num_of_Loan"].quantile(0.75)
Max= df["Num_of_Loan"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 11.0
# lower= -5.0

# %%
df[df["Num_of_Loan"]<lower_fence]
# Out:
#             ID Customer_ID     Month             Name  Age          SSN  \
# 31      0x162d  CUS_0xb891    August           Jasond   55  072-31-6145
# 34      0x1634  CUS_0x1cdb     March           Deepaa   21  615-06-7821
# 39      0x1639  CUS_0x1cdb    August           Deepaa   21  615-06-7821
# 53      0x164f  CUS_0x284a      June           Nadiaq   34  411-51-0676
# 61      0x165b  CUS_0x5407      June             Annk   30  500-92-6408
# ...        ...         ...       ...              ...  ...          ...
# 99877  0x25f37  CUS_0x3855      June            Xolai   35  963-55-7106
# 99901  0x25f5b  CUS_0x4986      June  Charles Abbotta   34  971-61-8388
# 99902  0x25f5c  CUS_0x4986      July  Charles Abbotta   34  971-61-8388
# 99969  0x25fc3   CUS_0xf16  February   Maria Sheahanb   45  868-70-2218
# 99987  0x25fdd  CUS_0x8600     April   Sarah McBridec   28  031-35-0942
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df[df["Num_of_Loan"]>upper_fence]
# Out:
#             ID Customer_ID     Month                Name  Age          SSN  \
# 21      0x161f  CUS_0x2dbc      June              Langep   34  486-85-3974
# 810     0x1ac0  CUS_0x6435     March   Alexei Oreskovicf   26  538-49-2118
# 1390    0x1e24  CUS_0x64ce      July              Lopezu   21  066-73-7172
# 2008    0x21c6  CUS_0x4256   January  Norihiko Shirouzun   21  030-61-4163
# 2273    0x2353   CUS_0xf59  February               Huntt   35  008-37-9819
# ...        ...         ...       ...                 ...  ...          ...
# 99743  0x25e6d  CUS_0x9674    August            Damounit   23  949-10-3104
# 99760  0x25e8a  CUS_0x1b07   January            Baldwinq   35  739-15-8297
# 99769  0x25e97  CUS_0xc345  February         Jeb Blountf   23  176-40-0757
# 99853  0x25f13  CUS_0x3048      June     Rick Rothackeru   40  375-64-6913
# 99919  0x25f75  CUS_0x1619    August         Phil Wahbao   54  683-59-7399
#
# ...

# %%
df.loc[df["Num_of_Loan"]<lower_fence,"Num_of_Loan"]=9

# %%
df[df["Num_of_Loan"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.loc[df["Num_of_Loan"]>upper_fence,"Num_of_Loan"]=10

# %%
df[df["Num_of_Loan"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df["Type_of_Loan"].isna().sum()
# Out:
# np.int64(10758)

# %%
df["Type_of_Loan"]
# Out:
# 0        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4        Auto Loan, Credit-Builder Loan, Personal Loan,...
#                                ...
# 99995                          Auto Loan, and Student Loan
# 99996                          Auto Loan, and Student Loan
# 99997                          Auto Loan, and Student Loan
# 99998                          Auto Loan, and Student Loan
# 99999                          Auto Loan, and Student Loan
# Name: Type_of_Loan, Length: 94428, dtype: object

# %%
df.dropna(subset='Type_of_Loan',inplace=True)

# %%
#df["Type_of_Loan"]=df["Type_of_Loan"].ffill()

# %%
df["Type_of_Loan"]
# Out:
# 0        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3        Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4        Auto Loan, Credit-Builder Loan, Personal Loan,...
#                                ...
# 99995                          Auto Loan, and Student Loan
# 99996                          Auto Loan, and Student Loan
# 99997                          Auto Loan, and Student Loan
# 99998                          Auto Loan, and Student Loan
# 99999                          Auto Loan, and Student Loan
# Name: Type_of_Loan, Length: 83670, dtype: object

# %%
df["Type_of_Loan"].isna().sum()
# Out:
# np.int64(0)

# %%
df[["Delay_from_due_date"]].isna().sum()
# Out:
# Delay_from_due_date    0
# dtype: int64

# %%
df["Delay_from_due_date"]
# Out:
# 0         3
# 1        -1
# 2         3
# 3         5
# 4         6
#          ..
# 99995    23
# 99996    18
# 99997    27
# 99998    20
# 99999    18
# Name: Delay_from_due_date, Length: 83670, dtype: int64

# %%
Mini= df["Delay_from_due_date"].min()
Q1= df["Delay_from_due_date"].quantile(0.25)
Q2= df["Delay_from_due_date"].quantile(0.50)
Q3= df["Delay_from_due_date"].quantile(0.75)
Max= df["Delay_from_due_date"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 57.5
# lower= -18.5

# %%
df[df["Delay_from_due_date"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Delay_from_due_date"]>upper_fence]
# Out:
#             ID Customer_ID     Month     Name  Age          SSN Occupation  \
# 232     0x175e  CUS_0xb681   January   Sarahb   37  904-88-7361    Manager
# 233     0x175f  CUS_0xb681  February   Sarahb   37  904-88-7361    Manager
# 234     0x1760  CUS_0xb681     March   Sarahb   37  904-88-7361    Manager
# 235     0x1761  CUS_0xb681     April   Sarahb   37  904-88-7361    Manager
# 236     0x1762  CUS_0xb681       May   Sarahb   37  904-88-7361    Manager
# ...        ...         ...       ...      ...  ...          ...        ...
# 99403  0x25c71  CUS_0x7b65     April  Sineadv   27  751-96-2010   Mechanic
# 99404  0x25c72  CUS_0x7b65       May  Sineadv   27  751-96-2010     Others
# 99405  0x25c73  CUS_0x7b65      June  Sineadv   27  751-96-2010   Mechanic
# 99406  0x25c74  CUS_0x7b65      July  Sineadv   27  751-96-2010   Mechanic
# 99407  0x25c75  CUS_0x7b65    August  Sineadv   28  751-96-2010   Mechanic
#
# ...

# %%
df.loc[df["Delay_from_due_date"]>upper_fence,"Delay_from_due_date"]=upper_fence

# %%
df[df["Delay_from_due_date"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Num_of_Delayed_Payment"]].isna().sum()
# Out:
# Num_of_Delayed_Payment    5831
# dtype: int64

# %%
df["Num_of_Delayed_Payment"]
# Out:
# 0          7
# 1        NaN
# 2          7
# 3          4
# 4        NaN
#         ...
# 99995      7
# 99996      7
# 99997      6
# 99998    NaN
# 99999      6
# Name: Num_of_Delayed_Payment, Length: 83670, dtype: object

# %%
df.dropna(subset='Num_of_Delayed_Payment',inplace=True)

# %%
df["Num_of_Delayed_Payment"]
# Out:
# 0         7
# 2         7
# 3         4
# 5         4
# 6        8_
#          ..
# 99994     6
# 99995     7
# 99996     7
# 99997     6
# 99999     6
# Name: Num_of_Delayed_Payment, Length: 77839, dtype: object

# %%
df["Num_of_Delayed_Payment"].isna().sum()
# Out:
# np.int64(0)

# %%
ls=[]
for i in df["Num_of_Delayed_Payment"]:
    text=str(i).split("_")[0]
    ls.append(text)

# %%
df["Num_of_Delayed_Payment"]=ls

# %%
df[["Changed_Credit_Limit"]].isna().sum()
# Out:
# Changed_Credit_Limit    0
# dtype: int64

# %%
df["Changed_Credit_Limit"]
# Out:
# 0        11.27
# 2            _
# 3         6.27
# 5         9.27
# 6        11.27
#          ...
# 99994      9.5
# 99995     11.5
# 99996     11.5
# 99997     11.5
# 99999     11.5
# Name: Changed_Credit_Limit, Length: 77839, dtype: object

# %%
df["Changed_Credit_Limit"]=df["Changed_Credit_Limit"].replace("_",np.nan)

# %%
df.head(10)
# Out:
#         ID Customer_ID     Month             Name  Age          SSN  \
# 0   0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265
# 2   0x1604   CUS_0xd40     March    Aaron Maashoh   35  821-00-0265
# 3   0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265
# 5   0x1607   CUS_0xd40      June    Aaron Maashoh   23  821-00-0265
# 6   0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265
# 8   0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9   0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839
# 10  0x1610  CUS_0x21b1     March  Rick Rothackerj   28  004-07-5839
# 11  0x1611  CUS_0x21b1     April  Rick Rothackerj   28  004-07-5839
# 12  0x1612  CUS_0x21b1       May  Rick Rothackerj   28  004-07-5839
#
#    Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0   Scientist       19114.12            1824.843333                  3  ...
# ...

# %%
df.dropna(subset='Changed_Credit_Limit',inplace=True)

# %%
df["Changed_Credit_Limit"]
# Out:
# 0        11.27
# 3         6.27
# 5         9.27
# 6        11.27
# 8         5.42
#          ...
# 99994      9.5
# 99995     11.5
# 99996     11.5
# 99997     11.5
# 99999     11.5
# Name: Changed_Credit_Limit, Length: 76194, dtype: object

# %%
df[["Num_Credit_Inquiries"]].isna().sum()
# Out:
# Num_Credit_Inquiries    1497
# dtype: int64

# %%
df.dropna(subset="Num_Credit_Inquiries",inplace=True)

# %%
df["Num_Credit_Inquiries"]
# Out:
# 0        4.0
# 3        4.0
# 5        4.0
# 6        4.0
# 8        2.0
#         ...
# 99994    3.0
# 99995    3.0
# 99996    3.0
# 99997    3.0
# 99999    3.0
# Name: Num_Credit_Inquiries, Length: 74697, dtype: float64

# %%
df["Num_Credit_Inquiries"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Num_Credit_Inquiries"].min()
Q1= df["Num_Credit_Inquiries"].quantile(0.25)
Q2= df["Num_Credit_Inquiries"].quantile(0.50)
Q3= df["Num_Credit_Inquiries"].quantile(0.75)
Max= df["Num_Credit_Inquiries"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 18.0
# lower= -6.0

# %%
df[df["Num_Credit_Inquiries"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Num_Credit_Inquiries"]>upper_fence]
# Out:
#             ID Customer_ID     Month            Name  Age          SSN  \
# 173     0x1703  CUS_0xa16e      June      Lee Chyenz   42  905-50-7912
# 193     0x1723  CUS_0xa5f9  February           Rickt   34  189-09-5267
# 198     0x1728  CUS_0xa5f9      July           Rickt   34  189-09-5267
# 234     0x1760  CUS_0xb681     March          Sarahb   37  904-88-7361
# 312     0x17d6  CUS_0x571f   January  Emily Flitterl   18  397-28-9675
# ...        ...         ...       ...             ...  ...          ...
# 99502  0x25d04  CUS_0xb5c3      July          Chucky   29  197-53-4663
# 99717  0x25e47  CUS_0xadbd      June          Scotts   26  864-24-3672
# 99769  0x25e97  CUS_0xc345  February     Jeb Blountf   23  176-40-0757
# 99789  0x25eb3  CUS_0x62f5      June         Alexein   54  272-40-2510
# 99872  0x25f32  CUS_0x3855   January           Xolai   27  963-55-7106
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Num_Credit_Inquiries"]>upper_fence,"Num_Credit_Inquiries"]=12

# %%
df[df["Num_Credit_Inquiries"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Credit_Mix"]].isna().sum()
# Out:
# Credit_Mix    0
# dtype: int64

# %%
df["Credit_Mix"]
# Out:
# 0           _
# 3        Good
# 5        Good
# 6        Good
# 8        Good
#          ...
# 99994       _
# 99995       _
# 99996       _
# 99997    Good
# 99999    Good
# Name: Credit_Mix, Length: 74697, dtype: object

# %%
df["Credit_Mix"]=df["Credit_Mix"].replace("_","Others")

# %%
df["Credit_Mix"]
# Out:
# 0        Others
# 3          Good
# 5          Good
# 6          Good
# 8          Good
#           ...
# 99994    Others
# 99995    Others
# 99996    Others
# 99997      Good
# 99999      Good
# Name: Credit_Mix, Length: 74697, dtype: object

# %%
df["Outstanding_Debt"].isna().sum()
# Out:
# np.int64(0)

# %%
df["Outstanding_Debt"]
# Out:
# 0        809.98
# 3        809.98
# 5        809.98
# 6        809.98
# 8        605.03
#           ...
# 99994    502.38
# 99995    502.38
# 99996    502.38
# 99997    502.38
# 99999    502.38
# Name: Outstanding_Debt, Length: 74697, dtype: object

# %%
ls=[]
for i in df["Outstanding_Debt"]:
    text= str(i).split("_")[0]
    ls.append(text)

# %%
df["Outstanding_Debt"]=ls

# %%
df["Outstanding_Debt"]=df["Outstanding_Debt"].astype("float")

# %%
df["Outstanding_Debt"].mean()
# Out:
# np.float64(1511.6510420766565)

# %%
Mini= df["Outstanding_Debt"].min()
Q1= df["Outstanding_Debt"].quantile(0.25)
Q2= df["Outstanding_Debt"].quantile(0.50)
Q3= df["Outstanding_Debt"].quantile(0.75)
Max= df["Outstanding_Debt"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 4438.62
# lower= -1692.82

# %%
df[df["Outstanding_Debt"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Outstanding_Debt"]>upper_fence]
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 481     0x18d3  CUS_0x7d0b  February  Isabel Reynoldsb   21  226-77-0587
# 482     0x18d4  CUS_0x7d0b     March  Isabel Reynoldsb   22  226-77-0587
# 484     0x18d6  CUS_0x7d0b       May  Isabel Reynoldsb   22  226-77-0587
# 485     0x18d7  CUS_0x7d0b      June  Isabel Reynoldsb   22  226-77-0587
# 486     0x18d8  CUS_0x7d0b      July  Isabel Reynoldsb   22  226-77-0587
# ...        ...         ...       ...               ...  ...          ...
# 99849  0x25f0f  CUS_0x3048  February   Rick Rothackeru   40  375-64-6913
# 99850  0x25f10  CUS_0x3048     March   Rick Rothackeru   40  375-64-6913
# 99851  0x25f11  CUS_0x3048     April   Rick Rothackeru   40  375-64-6913
# 99853  0x25f13  CUS_0x3048      June   Rick Rothackeru   40  375-64-6913
# 99855  0x25f15  CUS_0x3048    August   Rick Rothackeru   40  375-64-6913
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Outstanding_Debt"]>upper_fence,"Outstanding_Debt"]= upper_fence

# %%
df[df["Outstanding_Debt"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df["Credit_Utilization_Ratio"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Credit_Utilization_Ratio"].min()
Q1= df["Credit_Utilization_Ratio"].quantile(0.25)
Q2= df["Credit_Utilization_Ratio"].quantile(0.50)
Q3= df["Credit_Utilization_Ratio"].quantile(0.75)
Max= df["Credit_Utilization_Ratio"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 48.97982309692568
# lower= 15.359931173846142

# %%
df[df["Credit_Utilization_Ratio"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Credit_Utilization_Ratio"]>upper_fence]
# Out:
#             ID Customer_ID    Month      Name  Age          SSN  Occupation  \
# 68000  0x1a472  CUS_0x751c  January  Jessican   19  220-63-1416  Accountant
#
#        Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 68000           33.0           15090.076667                  5  ...
#
#        Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 68000        Good           1182.91                 49.564519
#
#           Credit_History_Age  Payment_of_Min_Amount Total_EMI_per_month  \
# 68000  25 Years and 5 Months                     No            74.73259
#
#       Amount_invested_monthly                Payment_Behaviour  \
# 68000      121.32898261998345  High_spent_Large_value_payments
#
#           Monthly_Balance  Credit_Score
# 68000  1552.9460937445635      Standard
#
# [1 rows x 28 columns]

# %%
df.loc[df["Credit_Utilization_Ratio"]>upper_fence,"Credit_Utilization_Ratio"]= 25.6

# %%
df[df["Credit_Utilization_Ratio"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Credit_History_Age"]].isna().sum()
# Out:
# Credit_History_Age    6768
# dtype: int64

# %%
df["Credit_History_Age"]
# Out:
# 0         22 Years and 1 Months
# 3         22 Years and 4 Months
# 5         22 Years and 6 Months
# 6         22 Years and 7 Months
# 8         26 Years and 7 Months
#                   ...
# 99994     31 Years and 5 Months
# 99995     31 Years and 6 Months
# 99996     31 Years and 7 Months
# 99997     31 Years and 8 Months
# 99999    31 Years and 10 Months
# Name: Credit_History_Age, Length: 74697, dtype: object

# %%
df.dropna(subset='Credit_History_Age',inplace=True)

# %%
df["Credit_History_Age"]
# Out:
# 0         22 Years and 1 Months
# 3         22 Years and 4 Months
# 5         22 Years and 6 Months
# 6         22 Years and 7 Months
# 8         26 Years and 7 Months
#                   ...
# 99994     31 Years and 5 Months
# 99995     31 Years and 6 Months
# 99996     31 Years and 7 Months
# 99997     31 Years and 8 Months
# 99999    31 Years and 10 Months
# Name: Credit_History_Age, Length: 67929, dtype: object

# %%
ls=[]
for i in df["Credit_History_Age"]:
    text=int(i.split()[0])*12+int(i.split()[3])
    ls.append(text)

# %%
df["Credit_History_Age"]=ls

# %%
df["Credit_History_Age"].mean()
# Out:
# np.float64(212.8311913910112)

# %%
df["Credit_History_Age"]
# Out:
# 0        265
# 3        268
# 5        270
# 6        271
# 8        319
#         ...
# 99994    377
# 99995    378
# 99996    379
# 99997    380
# 99999    382
# Name: Credit_History_Age, Length: 67929, dtype: int64

# %%
Mini= df["Credit_History_Age"].min()
Q1= df["Credit_History_Age"].quantile(0.25)
Q2= df["Credit_History_Age"].quantile(0.50)
Q3= df["Credit_History_Age"].quantile(0.75)
Max= df["Credit_History_Age"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 526.5
# lower= -101.5

# %%
df[df["Credit_History_Age"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Credit_History_Age"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Payment_of_Min_Amount"]].isna().sum()
# Out:
# Payment_of_Min_Amount    0
# dtype: int64

# %%
df["Payment_of_Min_Amount"]
# Out:
# 0        No
# 3        No
# 5        No
# 6        No
# 8        No
#          ..
# 99994    No
# 99995    No
# 99996    No
# 99997    No
# 99999    No
# Name: Payment_of_Min_Amount, Length: 67929, dtype: object

# %%
df[["Total_EMI_per_month"]].isna().sum()
# Out:
# Total_EMI_per_month    0
# dtype: int64

# %%
df["Total_EMI_per_month"]
# Out:
# 0        49.574949
# 3        49.574949
# 5        49.574949
# 6        49.574949
# 8        18.816215
#            ...
# 99994    35.104023
# 99995    35.104023
# 99996    35.104023
# 99997    35.104023
# 99999    35.104023
# Name: Total_EMI_per_month, Length: 67929, dtype: float64

# %%
Mini= df["Total_EMI_per_month"].min()
Q1= df["Total_EMI_per_month"].quantile(0.25)
Q2= df["Total_EMI_per_month"].quantile(0.50)
Q3= df["Total_EMI_per_month"].quantile(0.75)
Max= df["Total_EMI_per_month"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 369.62205811384
# lower= -154.98560048612194

# %%
df[df["Total_EMI_per_month"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Total_EMI_per_month"]>upper_fence]
# Out:
#             ID Customer_ID     Month             Name  Age          SSN  \
# 50      0x164c  CUS_0x284a     March           Nadiaq   34  411-51-0676
# 52      0x164e  CUS_0x284a       May           Nadiaq   34  411-51-0676
# 53      0x164f  CUS_0x284a      June           Nadiaq   34  411-51-0676
# 55      0x1651  CUS_0x284a    August           Nadiaq   34  411-51-0676
# 76      0x1672  CUS_0xba08       May           Jamesj   44  366-68-1681
# ...        ...         ...       ...              ...  ...          ...
# 99926  0x25f80  CUS_0x2654      July              enj   38  647-67-8889
# 99927  0x25f81  CUS_0x2654    August              enj   38  647-67-8889
# 99960  0x25fb6  CUS_0x372c   January  Lucia Mutikanik   18  340-85-7301
# 99970  0x25fc4   CUS_0xf16     March   Maria Sheahanb   45  868-70-2218
# 99985  0x25fdb  CUS_0x8600  February   Sarah McBridec   28  031-35-0942
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Total_EMI_per_month"]>upper_fence,"Total_EMI_per_month"]= upper_fence

# %%
df[df["Total_EMI_per_month"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Amount_invested_monthly"]].isna().sum()
# Out:
# Amount_invested_monthly    3059
# dtype: int64

# %%
df[["Amount_invested_monthly"]]
# Out:
#       Amount_invested_monthly
# 0           80.41529543900253
# 3           199.4580743910713
# 5          62.430172331195294
# 6           178.3440674122349
# 8            104.291825168246
# ...                       ...
# 99994      140.58140274528395
# 99995       60.97133255718485
# 99996       54.18595028760385
# 99997       24.02847744864441
# 99999       167.1638651610451
#
# [67929 rows x 1 columns]

# %%
ls = []
for i in df["Amount_invested_monthly"]:
    text = str(i).strip("__")
    number = text.split("_")[0]
    ls.append(number)

# %%
df["Amount_invested_monthly"]=ls

# %%
df["Amount_invested_monthly"]=df["Amount_invested_monthly"].astype("float")

# %%
mean= df["Amount_invested_monthly"].fillna(df["Amount_invested_monthly"].mean())
median= df["Amount_invested_monthly"].fillna(df["Amount_invested_monthly"].median())
std= df["Amount_invested_monthly"].fillna(df["Amount_invested_monthly"].std())
ffill= df["Amount_invested_monthly"].ffill()
bfill= df["Amount_invested_monthly"].bfill()
const= df["Amount_invested_monthly"].fillna(0)

# %%
print("the mean is=",mean.mean())
print("the median is=",median.mean())
print("the std is=",std.mean())
print("the ffill is=",ffill.mean())
print("the bfill is=",bfill.mean())
print("the const is=",const.mean())
# Out:
# the mean is= 641.7303401899972
# the median is= 618.7899679158736
# the std is= 705.7667460856791
# the ffill is= 642.408684012532
# the bfill is= 642.0534260083477
# the const is= 612.8317385523873

# %%
print("the actual mean is=",df["Amount_invested_monthly"].mean())
# Out:
# the actual mean is= 641.7303401899972

# %%
df["Amount_invested_monthly"].std()
# Out:
# np.float64(2063.740479479886)

# %%
ffill.std()
# Out:
# np.float64(2064.7323553477404)

# %%
bfill.std()
# Out:
# np.float64(2063.7877702527044)

# %%
df["Amount_invested_monthly"]=df["Amount_invested_monthly"].ffill()

# %%
df["Amount_invested_monthly"]
# Out:
# 0         80.415295
# 3        199.458074
# 5         62.430172
# 6        178.344067
# 8        104.291825
#             ...
# 99994    140.581403
# 99995     60.971333
# 99996     54.185950
# 99997     24.028477
# 99999    167.163865
# Name: Amount_invested_monthly, Length: 67929, dtype: float64

# %%
Mini= df["Amount_invested_monthly"].min()
Q1= df["Amount_invested_monthly"].quantile(0.25)
Q2= df["Amount_invested_monthly"].quantile(0.50)
Q3= df["Amount_invested_monthly"].quantile(0.75)
Max= df["Amount_invested_monthly"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 539.636843289245
# lower= -207.19109427067315

# %%
df[df["Amount_invested_monthly"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Amount_invested_monthly"]>upper_fence]
# Out:
#             ID Customer_ID     Month          Name  Age          SSN  \
# 23      0x1621  CUS_0x2dbc    August        Langep   34  486-85-3974
# 28      0x162a  CUS_0xb891       May        Jasond   55  072-31-6145
# 49      0x164b  CUS_0x284a  February        Nadiaq   34  411-51-0676
# 55      0x1651  CUS_0x284a    August        Nadiaq   34  411-51-0676
# 68      0x1666  CUS_0x4157       May  Charlie Zhur   23  070-19-1622
# ...        ...         ...       ...           ...  ...          ...
# 99894  0x25f50  CUS_0x89aa      July         Kwokw   38  018-63-7005
# 99919  0x25f75  CUS_0x1619    August   Phil Wahbao   54  683-59-7399
# 99923  0x25f7d  CUS_0x2654     April           enj   38  647-67-8889
# 99927  0x25f81  CUS_0x2654    August           enj   38  647-67-8889
# 99951  0x25fa5  CUS_0x51b3    August         Ryana   33  837-85-9800
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Amount_invested_monthly"]>upper_fence,"Amount_invested_monthly"]= upper_fence

# %%
df[df["Amount_invested_monthly"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Payment_Behaviour"]].isna().sum()
# Out:
# Payment_Behaviour    0
# dtype: int64

# %%
df["Payment_Behaviour"]
# Out:
# 0         High_spent_Small_value_payments
# 3          Low_spent_Small_value_payments
# 5                                  !@9#%8
# 6          Low_spent_Small_value_payments
# 8          Low_spent_Small_value_payments
#                        ...
# 99994    High_spent_Medium_value_payments
# 99995     High_spent_Large_value_payments
# 99996    High_spent_Medium_value_payments
# 99997     High_spent_Large_value_payments
# 99999                              !@9#%8
# Name: Payment_Behaviour, Length: 67929, dtype: object

# %%
df["Payment_Behaviour"]=df["Payment_Behaviour"].replace("!@9#%8",np.nan)

# %%
df.dropna(subset='Payment_Behaviour',inplace=True)

# %%
df["Payment_Behaviour"]
# Out:
# 0         High_spent_Small_value_payments
# 3          Low_spent_Small_value_payments
# 6          Low_spent_Small_value_payments
# 8          Low_spent_Small_value_payments
# 9         High_spent_Large_value_payments
#                        ...
# 99991     High_spent_Large_value_payments
# 99994    High_spent_Medium_value_payments
# 99995     High_spent_Large_value_payments
# 99996    High_spent_Medium_value_payments
# 99997     High_spent_Large_value_payments
# Name: Payment_Behaviour, Length: 62838, dtype: object

# %%
df.head(10)
# Out:
#         ID Customer_ID     Month             Name  Age          SSN  \
# 0   0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265
# 3   0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265
# 6   0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265
# 8   0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9   0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839
# 10  0x1610  CUS_0x21b1     March  Rick Rothackerj   28  004-07-5839
# 11  0x1611  CUS_0x21b1     April  Rick Rothackerj   28  004-07-5839
# 12  0x1612  CUS_0x21b1       May  Rick Rothackerj   28  004-07-5839
# 13  0x1613  CUS_0x21b1      June  Rick Rothackerj   28  004-07-5839
# 14  0x1614  CUS_0x21b1      July  Rick Rothackerj   28  004-07-5839
#
#    Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# 0   Scientist       19114.12            1824.843333                  3  ...
# ...

# %%
df[["Monthly_Balance"]].isna().sum()
# Out:
# Monthly_Balance    818
# dtype: int64

# %%
df["Monthly_Balance"]
# Out:
# 0        312.49408867943663
# 3        223.45130972736786
# 6         244.5653167062043
# 8        470.69062692529184
# 9         484.5912142650067
#                 ...
# 99991            337.362988
# 99994            410.256158
# 99995            479.866228
# 99996             496.65161
# 99997            516.809083
# Name: Monthly_Balance, Length: 62838, dtype: object

# %%
ls = []
for i in df["Monthly_Balance"]:
    text = str(i).strip("__")
    number = text.split("_")[0]
    ls.append(number)

# %%
df["Monthly_Balance"]=ls

# %%
df["Monthly_Balance"]=df["Monthly_Balance"].astype("float")

# %%
df["Monthly_Balance"].mean()
# Out:
# np.float64(-4.299688272600236e+22)

# %%
mean= df["Monthly_Balance"].fillna(df["Monthly_Balance"].mean())
median= df["Monthly_Balance"].fillna(df["Monthly_Balance"].median())
std= df["Monthly_Balance"].fillna(df["Monthly_Balance"].std())
ffill= df["Monthly_Balance"].ffill()
bfill= df["Monthly_Balance"].bfill()
const= df["Monthly_Balance"].fillna(0)

# %%
print("the mean is=",mean.mean())
print("the median is=",median.mean())
print("the std is=",std.mean())
print("the ffill is=",ffill.mean())
print("the bfill is=",bfill.mean())
print("the const is=",const.mean())
# Out:
# the mean is= -4.299688272600237e+22
# the median is= -4.243716647039477e+22
# the std is= 6.842107082786744e+21
# the ffill is= -4.243716647039477e+22
# the bfill is= -4.243716647039477e+22
# the const is= -4.243716647039477e+22

# %%
print("the actual mean is=",df["Monthly_Balance"].mean())
# Out:
# the actual mean is= -4.299688272600236e+22

# %%
df["Monthly_Balance"].std()
# Out:
# np.float64(3.785588009211272e+24)

# %%
ffill.std()
# Out:
# np.float64(3.7608704222240774e+24)

# %%
bfill.std()
# Out:
# np.float64(3.7608704222240774e+24)

# %%
df["Monthly_Balance"]=df["Monthly_Balance"].bfill()

# %%
df["Monthly_Balance"]
# Out:
# 0        312.494089
# 3        223.451310
# 6        244.565317
# 8        470.690627
# 9        484.591214
#             ...
# 99991    337.362988
# 99994    410.256158
# 99995    479.866228
# 99996    496.651610
# 99997    516.809083
# Name: Monthly_Balance, Length: 62838, dtype: float64

# %%
df["Monthly_Balance"].isna().sum()
# Out:
# np.int64(0)

# %%
Mini= df["Monthly_Balance"].min()
Q1= df["Monthly_Balance"].quantile(0.25)
Q2= df["Monthly_Balance"].quantile(0.50)
Q3= df["Monthly_Balance"].quantile(0.75)
Max= df["Monthly_Balance"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 718.6340754914097
# lower= -7.940739887321513

# %%
df[df["Monthly_Balance"]<lower_fence]
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 5545    0x367f  CUS_0x9885  February         Paul Dayl   17  186-49-9679
# 26177   0xaf63  CUS_0x5a90  February         Scuffhamq   45  264-53-1943
# 29158   0xc0d8  CUS_0x288d      July            Selamk   55  970-19-8342
# 35570   0xe66c  CUS_0x85e9     March      Anna Driveri   45  288-62-7562
# 60009  0x1759f  CUS_0xc06e  February            radenp   30  046-72-5387
# 75251  0x1ceed  CUS_0x57f3     April     Kristen Haysq   29  577-85-0830
# 82918  0x1fbd8  CUS_0x41bf      July          Doeringq   44  693-64-7611
# 83255  0x1fdd1  CUS_0x2f7e    August  Sabina Zawadzkif   31  109-48-2095
#
#        Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 5545    Developer      41086.400            3660.866667                  3
# 26177    Engineer      29728.310            2551.359167                  3
# 29158      Lawyer      30748.930            2572.410833                  1
# ...

# %%
df[df["Monthly_Balance"]>upper_fence]
# Out:
#             ID Customer_ID     Month              Name  Age          SSN  \
# 17      0x161b  CUS_0x2dbc  February            Langep   34  486-85-3974
# 20      0x161e  CUS_0x2dbc       May            Langep   34  486-85-3974
# 21      0x161f  CUS_0x2dbc      June            Langep   34  486-85-3974
# 22      0x1620  CUS_0x2dbc      July            Langep   34  486-85-3974
# 23      0x1621  CUS_0x2dbc    August            Langep   34  486-85-3974
# ...        ...         ...       ...               ...  ...          ...
# 99786  0x25eb0  CUS_0x62f5     March           Alexein   54  272-40-2510
# 99872  0x25f32  CUS_0x3855   January             Xolai   27  963-55-7106
# 99888  0x25f4a  CUS_0x89aa   January  Yantoultra Nguif   38  018-63-7005
# 99890  0x25f4c  CUS_0x89aa     March             Kwokw   38  018-63-7005
# 99922  0x25f7c  CUS_0x2654     March               enj   38  647-67-8889
#
#           Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.loc[df["Monthly_Balance"]<lower_fence,"Monthly_Balance"]=lower_fence

# %%
df[df["Monthly_Balance"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df.loc[df["Monthly_Balance"]>upper_fence,"Monthly_Balance"]=upper_fence

# %%
df[df["Monthly_Balance"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[["Credit_Score"]].isna().sum()
# Out:
# Credit_Score    0
# dtype: int64

# %%
df["Credit_Score"]
# Out:
# 0            Good
# 3            Good
# 6            Good
# 8        Standard
# 9            Good
#            ...
# 99991    Standard
# 99994        Poor
# 99995        Poor
# 99996        Poor
# 99997        Poor
# Name: Credit_Score, Length: 62838, dtype: object

# %%
df[["Annual_Income"]].isna().sum()
# Out:
# Annual_Income    0
# dtype: int64

# %%
df["Annual_Income"].astype("float")
# Out:
# 0        19114.12
# 3        19114.12
# 6        19114.12
# 8        34847.84
# 9        34847.84
#            ...
# 99991    20002.88
# 99994    39628.99
# 99995    39628.99
# 99996    39628.99
# 99997    39628.99
# Name: Annual_Income, Length: 62838, dtype: float64

# %%
Mini= df["Annual_Income"].min()
Q1= df["Annual_Income"].quantile(0.25)
Q2= df["Annual_Income"].quantile(0.50)
Q3= df["Annual_Income"].quantile(0.75)
Max= df["Annual_Income"].max()

IQR= Q3-Q1
upper_fence= Q3+(1.5*IQR)
lower_fence= Q1-(1.5*IQR)

# %%
print("upper=",upper_fence)
print("lower=",lower_fence)
# Out:
# upper= 139573.62
# lower= -54983.659999999996

# %%
df[df["Annual_Income"]<lower_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
df[df["Annual_Income"]>upper_fence]
# Out:
#             ID Customer_ID     Month    Name  Age          SSN     Occupation  \
# 17      0x161b  CUS_0x2dbc  February  Langep   34  486-85-3974       Engineer
# 20      0x161e  CUS_0x2dbc       May  Langep   34  486-85-3974         Others
# 21      0x161f  CUS_0x2dbc      June  Langep   34  486-85-3974       Engineer
# 22      0x1620  CUS_0x2dbc      July  Langep   34  486-85-3974       Engineer
# 23      0x1621  CUS_0x2dbc    August  Langep   34  486-85-3974       Engineer
# ...        ...         ...       ...     ...  ...          ...            ...
# 99923  0x25f7d  CUS_0x2654     April     enj   38  647-67-8889  Media_Manager
# 99924  0x25f7e  CUS_0x2654       May     enj   38  647-67-8889  Media_Manager
# 99925  0x25f7f  CUS_0x2654      June     enj   38  647-67-8889  Media_Manager
# 99926  0x25f80  CUS_0x2654      July     enj   38  647-67-8889  Media_Manager
# 99927  0x25f81  CUS_0x2654    August     enj   38  647-67-8889  Media_Manager
#
# ...

# %%
df.loc[df["Annual_Income"]>upper_fence,"Annual_Income"]= 20.0

# %%
df[df["Annual_Income"]>upper_fence]
# Out:
# Empty DataFrame
# Columns: [ID, Customer_ID, Month, Name, Age, SSN, Occupation, Annual_Income, Monthly_Inhand_Salary, Num_Bank_Accounts, Num_Credit_Card, Interest_Rate, Num_of_Loan, Type_of_Loan, Delay_from_due_date, Num_of_Delayed_Payment, Changed_Credit_Limit, Num_Credit_Inquiries, Credit_Mix, Outstanding_Debt, Credit_Utilization_Ratio, Credit_History_Age, Payment_of_Min_Amount, Total_EMI_per_month, Amount_invested_monthly, Payment_Behaviour, Monthly_Balance, Credit_Score]
# Index: []
#
# [0 rows x 28 columns]

# %%
pd.set_option("display.max_columns",None)

# %%
df
# Out:
#             ID Customer_ID     Month             Name  Age          SSN  \
# 0       0x1602   CUS_0xd40   January    Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April    Aaron Maashoh   23  821-00-0265
# 6       0x1608   CUS_0xd40      July    Aaron Maashoh   23  821-00-0265
# 8       0x160e  CUS_0x21b1   January  Rick Rothackerj   28  004-07-5839
# 9       0x160f  CUS_0x21b1  February  Rick Rothackerj   28  004-07-5839
# ...        ...         ...       ...              ...  ...          ...
# 99991  0x25fe1  CUS_0x8600    August   Sarah McBridec   29  031-35-0942
# 99994  0x25fe8  CUS_0x942c     March            Nicks   25  078-73-5990
# 99995  0x25fe9  CUS_0x942c     April            Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May            Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June            Nicks   25  078-73-5990
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# ...

# %%
df.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Delay_from_due_date         0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Num_Credit_Inquiries        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %%
sns.boxplot(data=df)
plt.xticks(rotation=100);

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
df.drop(columns=["Name", "Customer_ID", "ID", "Payment_Behaviour","SSN","Outstanding_Debt","Type_of_Loan"], inplace=True)

# %%
en_data= ['Month','Credit_Mix','Payment_of_Min_Amount']

# %%
ordinal= OrdinalEncoder()

# %%
df[en_data]= ordinal.fit_transform(df[en_data])

# %%
df
# Out:
#        Month  Age Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0        3.0   23  Scientist       19114.12            1824.843333
# 3        0.0   23  Scientist       19114.12            1824.843333
# 6        4.0   23  Scientist       19114.12            1824.843333
# 8        3.0   28     Others       34847.84            3037.986667
# 9        2.0   28    Teacher       34847.84            3037.986667
# ...      ...  ...        ...            ...                    ...
# 99991    1.0   29  Architect       20002.88            1929.906667
# 99994    6.0   25   Mechanic       39628.99            3359.415833
# 99995    0.0   25   Mechanic       39628.99            3359.415833
# 99996    7.0   25   Mechanic       39628.99            3359.415833
# 99997    5.0   25   Mechanic       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3              4.0              3            4
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label= LabelEncoder()

# %%
df['Credit_Score']=label.fit_transform(df['Credit_Score'])

# %%
df['Occupation']=label.fit_transform(df['Occupation'])

# %%
df.reset_index(inplace=True)

# %%
x= df.drop("Credit_Score",axis=1)
y=df["Credit_Score"]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mn= MinMaxScaler()

# %%
cols= x.columns

# %%
x= mn.fit_transform(x)

# %%
x= pd.DataFrame(x,columns=cols)
x
# Out:
#          index     Month       Age  Occupation  Annual_Income  \
# 0      0.00000  0.428571  0.214286    0.866667       0.136857
# 1      0.00003  0.000000  0.214286    0.866667       0.136857
# 2      0.00006  0.571429  0.214286    0.866667       0.136857
# 3      0.00008  0.428571  0.333333    0.800000       0.249629
# 4      0.00009  0.285714  0.333333    0.933333       0.249629
# ...        ...       ...       ...         ...            ...
# 62833  0.99994  0.142857  0.357143    0.066667       0.143228
# 62834  0.99997  0.857143  0.261905    0.600000       0.283898
# 62835  0.99998  0.000000  0.261905    0.600000       0.283898
# 62836  0.99999  1.000000  0.261905    0.600000       0.283898
# 62837  1.00000  0.714286  0.261905    0.600000       0.283898
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                   0.102087           0.333333         0.363636
# 1                   0.102087           0.333333         0.363636
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,shuffle=True,random_state=45,test_size=0.2,stratify=y)

# %%
import statsmodels.api as sm

# %%
x_train= sm.add_constant(x_train)

# %%
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

# %%
model= sm.GLM(y_train,x_train,family=sm.families.Binomial()).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ...
# Dep. Variable:           Credit_Score   No. Observations:                50270
# Model:                            GLM   Df Residuals:                    50248
# Model Family:                Binomial   Df Model:                           21
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                    nan
# Date:                Sat, 06 Jul 2024   Deviance:                   2.7575e+06
# Time:                        13:45:24   Pearson chi2:                 1.59e+20
# No. Iterations:                    22   Pseudo R-squ. (CS):                nan
# Covariance Type:            nonrobust
# ...
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif= {x_train.columns[i]: variance_inflation_factor(x_train,i) for i in range(1,x_train.shape[1])}

# %%
vif
# Out:
# {'index': np.float64(1.0010486212495733),
#  'Month': np.float64(1.0003512752707155),
#  'Age': np.float64(1.0826048312830612),
#  'Occupation': np.float64(1.0011376723592698),
#  'Annual_Income': np.float64(2.1068930390102754),
#  'Monthly_Inhand_Salary': np.float64(4.439341814760184),
#  'Num_Bank_Accounts': np.float64(1.8032431624189365),
#  'Num_Credit_Card': np.float64(1.4843947223933331),
#  'Interest_Rate': np.float64(2.203939137138141),
#  'Num_of_Loan': np.float64(1.9239746272068174),
#  'Delay_from_due_date': np.float64(1.9393110776282596),
#  'Num_of_Delayed_Payment': np.float64(1.0008565416998),
#  'Changed_Credit_Limit': np.float64(1.3065428133099437),
#  'Num_Credit_Inquiries': np.float64(2.0610962960167094),
#  'Credit_Mix': np.float64(1.2330611570668077),
#  'Credit_Utilization_Ratio': np.float64(1.045793497292458),
#  'Credit_History_Age': np.float64(2.0845717324552044),
#  'Payment_of_Min_Amount': np.float64(1.3176060944876569),
# ...

# %%
x_train.drop("Monthly_Inhand_Salary",inplace=True,axis=1)

# %%
model = sm.OLS(y_train,x_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Credit_Score   R-squared:                       0.130
# Model:                            OLS   Adj. R-squared:                  0.129
# Method:                 Least Squares   F-statistic:                     374.3
# Date:                Sat, 06 Jul 2024   Prob (F-statistic):               0.00
# Time:                        13:47:09   Log-Likelihood:                -53048.
# No. Observations:               50270   AIC:                         1.061e+05
# Df Residuals:                   50249   BIC:                         1.063e+05
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                        0.4836      0.028     17.271      0.000       0.429       0.538
# ...

# %%
vif_0= {x_train.columns[i]: variance_inflation_factor(x_train,i) for i in range(1,x_train.shape[1])}
vif_0
# Out:
# {'index': np.float64(1.000912512318119),
#  'Month': np.float64(1.000331198477482),
#  'Age': np.float64(1.0825024303206137),
#  'Occupation': np.float64(1.0011352131512086),
#  'Annual_Income': np.float64(2.0208003041177336),
#  'Num_Bank_Accounts': np.float64(1.8000017119791154),
#  'Num_Credit_Card': np.float64(1.4841080877497803),
#  'Interest_Rate': np.float64(2.2028295508081643),
#  'Num_of_Loan': np.float64(1.9237200525335638),
#  'Delay_from_due_date': np.float64(1.9386426256162226),
#  'Num_of_Delayed_Payment': np.float64(1.0008283007520944),
#  'Changed_Credit_Limit': np.float64(1.306401751673118),
#  'Num_Credit_Inquiries': np.float64(2.0602529572582355),
#  'Credit_Mix': np.float64(1.229803563472147),
#  'Credit_Utilization_Ratio': np.float64(1.0433832825840836),
#  'Credit_History_Age': np.float64(2.084368418977873),
#  'Payment_of_Min_Amount': np.float64(1.3174494439513078),
#  'Total_EMI_per_month': np.float64(1.5816544755518982),
# ...

# %%
x_test= sm.add_constant(x_test)

# %%
x_test= x_test[x_train.columns]

# %%
x_test
# Out:
#        const     index     Month       Age  Occupation  Annual_Income  \
# 15748    1.0  0.250158  0.142857  0.357143    0.000000       0.101559
# 46245    1.0  0.733952  0.285714  0.595238    0.133333       0.418301
# 1408     1.0  0.022621  0.571429  0.523810    0.200000       0.134207
# 50705    1.0  0.804694  0.000000  0.595238    1.000000       0.905175
# 7236     1.0  0.116073  0.142857  0.904762    0.733333       0.627989
# ...      ...       ...       ...       ...         ...            ...
# 53529    1.0  0.849425  1.000000  0.500000    0.466667       0.106720
# 36814    1.0  0.583388  0.285714  0.023810    0.466667       0.072894
# 5278     1.0  0.084853  0.714286  0.357143    0.466667       0.145604
# 19457    1.0  0.309919  0.142857  0.642857    0.466667       0.518712
# 28550    1.0  0.452684  0.000000  0.047619    0.400000       0.223030
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
prediction= model.predict(x_test)

# %%
prediction
# Out:
# 15748    1.533294
# 46245    1.666060
# 1408     1.234238
# 50705    1.276838
# 7236     0.865680
#            ...
# 53529    1.721213
# 36814    1.764021
# 5278     1.665133
# 19457    1.682289
# 28550    1.393446
# Length: 12568, dtype: float64

# %%
y_test
# Out:
# 15748    1
# 46245    1
# 1408     2
# 50705    1
# 7236     2
#         ..
# 53529    1
# 36814    2
# 5278     1
# 19457    2
# 28550    2
# Name: Credit_Score, Length: 12568, dtype: int64

# %%
c= list(range(109))
plt.figure(figsize=(8,4))
plt.scatter(y_test,prediction, label='prediction',color="green")
plt.show()

# %%
# above graph is not linear that's why we don't use linear regression

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg= LogisticRegression()

# %%
#rfe= RFE(estimator=lg,n_features_to_select=15)

# %%
#rfe.fit(x_train,y_train)

# %%
##rfe.estimator

# %%
#rfe.support_

# %%
#x_train= x_train[x_train.columns[rfe.support_]]

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lg.score(x_train,y_train)
# Out:
# 0.644937338372787

# %%
x_test= sm.add_constant(x_test)

# %%
#x_test= x_test[x_test.columns[rfe.support_]]

# %%
lg.score(x_test,y_test)
# Out:
# 0.6478357733927435

# %%
pred= lg.predict(x_test)

# %%
pred
# Out:
# array([2, 1, 1, ..., 2, 2, 2])

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score,f1_score,fbeta_score,auc

# %%
print(confusion_matrix(pred,y_test))
# Out:
# [[1007  161  557]
#  [  37 2119 1028]
#  [ 991 1652 5016]]

# %%
print(accuracy_score(pred,y_test))
# Out:
# 0.6478357733927435
